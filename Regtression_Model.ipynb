# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
import pandas as pd
import numpy as np

# %%
# Membaca dataset dengan delimiter yang benar (;)
data = pd.read_csv('winequality-red.csv', delimiter=';')

# Menampilkan beberapa baris pertama untuk memastikan data terbaca dengan benar
print(data.head())

# Menampilkan beberapa baris pertama untuk melihat data secara umum
data.head()

X = data.iloc[:, :-1].values  # Fitur (semua kolom kecuali 'quality')
y = data.iloc[:, -1].values  # Target (kolom 'quality')
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# Normalize features and target
X = (X - X.mean(axis=0)) / X.std(axis=0)  # Normalisasi fitur (mean=0, std=1)
y = (y - y.mean()) / y.std()  # Normalisasi target untuk regresi

# %%
# PyTorch Dataset class untuk menangani data
class WineDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)  # Konversi fitur ke tensor PyTorch
        self.y = torch.tensor(y, dtype=torch.float32)  # Konversi target ke tensor PyTorch

    def __len__(self):
        return len(self.X)  # Mengembalikan jumlah data

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]  # Mengembalikan pasangan fitur dan target



# Buat dataset PyTorch
dataset = WineDataset(X, y)

# %%
# Split dataset menjadi 80% training dan 20% testing
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# %%
# Definisi model MLP (Multilayer Perceptron)
class MLPRegressor(nn.Module):
    def __init__(self, input_size, hidden_layers, activation_fn):
        super(MLPRegressor, self).__init__()
        layers = []
        in_features = input_size  # Input size (jumlah fitur)
        for neurons in hidden_layers:
            layers.append(nn.Linear(in_features, neurons))  # Tambahkan layer linear
            layers.append(activation_fn)  # Tambahkan fungsi aktivasi
            in_features = neurons  # Update jumlah neuron untuk layer berikutnya
        layers.append(nn.Linear(in_features, 1))  # Output layer (satu neuron untuk regresi)
        self.model = nn.Sequential(*layers)  # Gabungkan semua layer menjadi satu model

    def forward(self, x):
        return self.model(x)  # Forward pass (prediksi)

# %%
# Parameter eksperimen yang akan diuji
hidden_layer_configs = [[4], [8], [16], [4, 8], [8, 16], [16, 32], [4, 8, 16]]  # Kombinasi jumlah neuron
activation_functions = {'linear': nn.Identity(), 'sigmoid': nn.Sigmoid(), 'relu': nn.ReLU(), 'softmax': nn.Softmax(dim=-1), 'tanh': nn.Tanh()}  # Fungsi aktivasi
epochs_list = [ 10, 25, 50]  # Jumlah epoch
learning_rates = [ 0.01, 0.001, 0.0001]  # Learning rate
batch_sizes = [16, 32, 64 ]  # Ukuran batch
# Untuk menyimpan hasil
results = []

# %%
# Gunakan GPU jika tersedia, jika tidak gunakan CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Loop untuk menguji semua kombinasi parameter
for hidden_layers in hidden_layer_configs:
    for act_name, activation_fn in activation_functions.items():
        for epochs in epochs_list:
            for lr in learning_rates:
                for batch_size in batch_sizes:
                    # Buat DataLoader untuk batching data
                    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
                    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

                    # Buat model, loss function, dan optimizer
                    model = MLPRegressor(X.shape[1], hidden_layers, activation_fn).to(device)  # Model MLP
                    criterion = nn.MSELoss()  # Mean Squared Error untuk regresi
                    optimizer = optim.Adam(model.parameters(), lr=lr)  # Optimizer Adam

                    # Training loop
                    model.train()
                    for epoch in range(epochs):
                        for inputs, targets in train_loader:
                            inputs, targets = inputs.to(device), targets.to(device)  # Pindahkan data ke GPU/CPU
                            optimizer.zero_grad()  # Reset gradien
                            outputs = model(inputs).squeeze()  # Forward pass
                            loss = criterion(outputs, targets)  # Hitung loss
                            loss.backward()  # Backpropagation
                            optimizer.step()  # Update bobot model

                    # Evaluation (uji model)
                    model.eval()
                    test_loss = 0
                    with torch.no_grad():  # Nonaktifkan gradien selama evaluasi
                        for inputs, targets in test_loader:
                            inputs, targets = inputs.to(device), targets.to(device)
                            outputs = model(inputs).squeeze()
                            test_loss += criterion(outputs, targets).item()  # Hitung loss untuk data uji

                    test_loss /= len(test_loader)  # Rata-rata loss
                    # Simpan hasil
                    results.append((hidden_layers, act_name, epochs, lr, batch_size, test_loss))
                    print(f"Hidden Layers: {hidden_layers}, Activation: {act_name}, Epochs: {epochs}, LR: {lr}, Batch Size: {batch_size}, Test Loss: {test_loss:.4f}")
# Out:
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6186
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6702
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6478
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6392
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6234
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.6567
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.8032
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 1.0866
# Hidden Layers: [4], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.1093
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6381
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6351
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6321
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6362
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6291
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6341
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.7588
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 1.0325
# Hidden Layers: [4], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 1.0339
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6327
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6432
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6319
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6355
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6323
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6283
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6403
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6935
# Hidden Layers: [4], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.8368
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6246
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6232
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6335
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6463
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.8308
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.8870
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 1.5500
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 1.0963
# Hidden Layers: [4], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.8887
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6214
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6101
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6273
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6272
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6356
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.8598
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.8529
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9456
# Hidden Layers: [4], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 1.4628
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6008
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6068
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6128
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6283
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6310
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6413
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.8425
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.9691
# Hidden Layers: [4], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.9486
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6416
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.5887
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6372
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6264
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6562
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.7282
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 1.0298
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 1.4698
# Hidden Layers: [4], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.0651
# Hidden Layers: [4], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.5901
# Hidden Layers: [4], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6176
# Hidden Layers: [4], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6090
# Hidden Layers: [4], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6193
# Hidden Layers: [4], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6145
# Hidden Layers: [4], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6575
# Hidden Layers: [4], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.8801
# Hidden Layers: [4], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9572
# Hidden Layers: [4], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.8665
# Hidden Layers: [4], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6264
# Hidden Layers: [4], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6246
# Hidden Layers: [4], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5853
# Hidden Layers: [4], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.5975
# Hidden Layers: [4], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6085
# Hidden Layers: [4], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6135
# Hidden Layers: [4], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6847
# Hidden Layers: [4], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.8442
# Hidden Layers: [4], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 1.0303
# Hidden Layers: [4], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6297
# Hidden Layers: [4], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6375
# Hidden Layers: [4], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6228
# Hidden Layers: [4], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6695
# Hidden Layers: [4], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.7698
# Hidden Layers: [4], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.8643
# Hidden Layers: [4], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.9644
# Hidden Layers: [4], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.9642
# Hidden Layers: [4], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.0188
# Hidden Layers: [4], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6188
# Hidden Layers: [4], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6248
# Hidden Layers: [4], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6168
# Hidden Layers: [4], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6265
# Hidden Layers: [4], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6397
# Hidden Layers: [4], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6936
# Hidden Layers: [4], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.9890
# Hidden Layers: [4], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.8890
# Hidden Layers: [4], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 1.0232
# Hidden Layers: [4], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6183
# Hidden Layers: [4], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6080
# Hidden Layers: [4], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6384
# Hidden Layers: [4], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6213
# Hidden Layers: [4], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6359
# Hidden Layers: [4], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6458
# Hidden Layers: [4], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.7510
# Hidden Layers: [4], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.8322
# Hidden Layers: [4], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.9312
# Hidden Layers: [4], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.5944
# Hidden Layers: [4], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6044
# Hidden Layers: [4], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6081
# Hidden Layers: [4], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6240
# Hidden Layers: [4], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6668
# Hidden Layers: [4], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.6444
# Hidden Layers: [4], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.9637
# Hidden Layers: [4], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.8831
# Hidden Layers: [4], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.0165
# Hidden Layers: [4], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6184
# Hidden Layers: [4], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6119
# Hidden Layers: [4], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.5762
# Hidden Layers: [4], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6248
# Hidden Layers: [4], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6296
# Hidden Layers: [4], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6281
# Hidden Layers: [4], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.6800
# Hidden Layers: [4], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.8020
# Hidden Layers: [4], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.9571
# Hidden Layers: [4], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6102
# Hidden Layers: [4], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.5995
# Hidden Layers: [4], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5912
# Hidden Layers: [4], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6037
# Hidden Layers: [4], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6043
# Hidden Layers: [4], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6275
# Hidden Layers: [4], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6317
# Hidden Layers: [4], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6893
# Hidden Layers: [4], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.7879
# Hidden Layers: [8], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6357
# Hidden Layers: [8], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6377
# Hidden Layers: [8], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6282
# Hidden Layers: [8], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6353
# Hidden Layers: [8], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6367
# Hidden Layers: [8], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.6583
# Hidden Layers: [8], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.6945
# Hidden Layers: [8], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 1.0732
# Hidden Layers: [8], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.9121
# Hidden Layers: [8], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6356
# Hidden Layers: [8], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6283
# Hidden Layers: [8], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6255
# Hidden Layers: [8], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6302
# Hidden Layers: [8], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6313
# Hidden Layers: [8], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6306
# Hidden Layers: [8], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.7595
# Hidden Layers: [8], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.6968
# Hidden Layers: [8], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.7622
# Hidden Layers: [8], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6242
# Hidden Layers: [8], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6295
# Hidden Layers: [8], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6302
# Hidden Layers: [8], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6351
# Hidden Layers: [8], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6305
# Hidden Layers: [8], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6311
# Hidden Layers: [8], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6266
# Hidden Layers: [8], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6494
# Hidden Layers: [8], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.6687
# Hidden Layers: [8], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6126
# Hidden Layers: [8], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6289
# Hidden Layers: [8], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6371
# Hidden Layers: [8], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6351
# Hidden Layers: [8], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6682
# Hidden Layers: [8], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.8086
# Hidden Layers: [8], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.9413
# Hidden Layers: [8], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 1.0386
# Hidden Layers: [8], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.0518
# Hidden Layers: [8], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6062
# Hidden Layers: [8], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6090
# Hidden Layers: [8], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6243
# Hidden Layers: [8], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6280
# Hidden Layers: [8], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6296
# Hidden Layers: [8], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6422
# Hidden Layers: [8], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.8486
# Hidden Layers: [8], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9362
# Hidden Layers: [8], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.9711
# Hidden Layers: [8], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.5920
# Hidden Layers: [8], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.5767
# Hidden Layers: [8], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5867
# Hidden Layers: [8], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6246
# Hidden Layers: [8], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6283
# Hidden Layers: [8], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6281
# Hidden Layers: [8], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6703
# Hidden Layers: [8], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.8398
# Hidden Layers: [8], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.8796
# Hidden Layers: [8], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.5823
# Hidden Layers: [8], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.5984
# Hidden Layers: [8], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.5931
# Hidden Layers: [8], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6174
# Hidden Layers: [8], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6314
# Hidden Layers: [8], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.7102
# Hidden Layers: [8], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.8428
# Hidden Layers: [8], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.8727
# Hidden Layers: [8], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.9332
# Hidden Layers: [8], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.5854
# Hidden Layers: [8], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6187
# Hidden Layers: [8], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.5953
# Hidden Layers: [8], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6061
# Hidden Layers: [8], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6068
# Hidden Layers: [8], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6410
# Hidden Layers: [8], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.7525
# Hidden Layers: [8], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9154
# Hidden Layers: [8], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.9150
# Hidden Layers: [8], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.5738
# Hidden Layers: [8], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6327
# Hidden Layers: [8], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5660
# Hidden Layers: [8], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.5942
# Hidden Layers: [8], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.5845
# Hidden Layers: [8], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.5926
# Hidden Layers: [8], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6279
# Hidden Layers: [8], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6673
# Hidden Layers: [8], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.7914
# Hidden Layers: [8], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.5963
# Hidden Layers: [8], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6057
# Hidden Layers: [8], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6318
# Hidden Layers: [8], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6684
# Hidden Layers: [8], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.7966
# Hidden Layers: [8], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.8550
# Hidden Layers: [8], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.9823
# Hidden Layers: [8], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.9285
# Hidden Layers: [8], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.0479
# Hidden Layers: [8], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6095
# Hidden Layers: [8], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.5841
# Hidden Layers: [8], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6104
# Hidden Layers: [8], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6426
# Hidden Layers: [8], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6369
# Hidden Layers: [8], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6856
# Hidden Layers: [8], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.8671
# Hidden Layers: [8], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9352
# Hidden Layers: [8], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.9565
# Hidden Layers: [8], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6021
# Hidden Layers: [8], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6131
# Hidden Layers: [8], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6036
# Hidden Layers: [8], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6138
# Hidden Layers: [8], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6024
# Hidden Layers: [8], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6377
# Hidden Layers: [8], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.8015
# Hidden Layers: [8], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.8789
# Hidden Layers: [8], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.9356
# Hidden Layers: [8], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6036
# Hidden Layers: [8], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6051
# Hidden Layers: [8], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6037
# Hidden Layers: [8], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6315
# Hidden Layers: [8], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6551
# Hidden Layers: [8], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.6381
# Hidden Layers: [8], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.8806
# Hidden Layers: [8], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.9397
# Hidden Layers: [8], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.8601
# Hidden Layers: [8], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.5805
# Hidden Layers: [8], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.5685
# Hidden Layers: [8], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.5647
# Hidden Layers: [8], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6126
# Hidden Layers: [8], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6292
# Hidden Layers: [8], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6392
# Hidden Layers: [8], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.7165
# Hidden Layers: [8], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.7909
# Hidden Layers: [8], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.7911
# Hidden Layers: [8], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6011
# Hidden Layers: [8], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6134
# Hidden Layers: [8], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5835
# Hidden Layers: [8], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.5972
# Hidden Layers: [8], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6086
# Hidden Layers: [8], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6259
# Hidden Layers: [8], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6315
# Hidden Layers: [8], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6571
# Hidden Layers: [8], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.6738
# Hidden Layers: [16], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6249
# Hidden Layers: [16], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6601
# Hidden Layers: [16], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6255
# Hidden Layers: [16], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6360
# Hidden Layers: [16], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6245
# Hidden Layers: [16], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.6397
# Hidden Layers: [16], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.7057
# Hidden Layers: [16], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.7261
# Hidden Layers: [16], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.5413
# Hidden Layers: [16], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6412
# Hidden Layers: [16], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6319
# Hidden Layers: [16], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6301
# Hidden Layers: [16], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6292
# Hidden Layers: [16], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6314
# Hidden Layers: [16], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6327
# Hidden Layers: [16], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.6493
# Hidden Layers: [16], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.6555
# Hidden Layers: [16], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.8344
# Hidden Layers: [16], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6780
# Hidden Layers: [16], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6263
# Hidden Layers: [16], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6471
# Hidden Layers: [16], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6369
# Hidden Layers: [16], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6315
# Hidden Layers: [16], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6296
# Hidden Layers: [16], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6338
# Hidden Layers: [16], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6361
# Hidden Layers: [16], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.7280
# Hidden Layers: [16], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6068
# Hidden Layers: [16], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6335
# Hidden Layers: [16], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6317
# Hidden Layers: [16], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6359
# Hidden Layers: [16], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6491
# Hidden Layers: [16], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.7729
# Hidden Layers: [16], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.8955
# Hidden Layers: [16], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.9264
# Hidden Layers: [16], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.9647
# Hidden Layers: [16], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.5884
# Hidden Layers: [16], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.5982
# Hidden Layers: [16], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6047
# Hidden Layers: [16], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6328
# Hidden Layers: [16], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6335
# Hidden Layers: [16], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6353
# Hidden Layers: [16], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.7643
# Hidden Layers: [16], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.8421
# Hidden Layers: [16], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.8951
# Hidden Layers: [16], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6041
# Hidden Layers: [16], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.5939
# Hidden Layers: [16], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5829
# Hidden Layers: [16], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6263
# Hidden Layers: [16], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6307
# Hidden Layers: [16], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6310
# Hidden Layers: [16], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6512
# Hidden Layers: [16], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6987
# Hidden Layers: [16], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.8702
# Hidden Layers: [16], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6039
# Hidden Layers: [16], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.5642
# Hidden Layers: [16], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.5874
# Hidden Layers: [16], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6239
# Hidden Layers: [16], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6132
# Hidden Layers: [16], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.6205
# Hidden Layers: [16], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.7332
# Hidden Layers: [16], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.8789
# Hidden Layers: [16], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.0902
# Hidden Layers: [16], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6027
# Hidden Layers: [16], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6053
# Hidden Layers: [16], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6079
# Hidden Layers: [16], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.5810
# Hidden Layers: [16], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6111
# Hidden Layers: [16], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6046
# Hidden Layers: [16], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.7033
# Hidden Layers: [16], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.7502
# Hidden Layers: [16], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.8620
# Hidden Layers: [16], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6265
# Hidden Layers: [16], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6107
# Hidden Layers: [16], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6306
# Hidden Layers: [16], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.5779
# Hidden Layers: [16], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.5916
# Hidden Layers: [16], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.5932
# Hidden Layers: [16], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6293
# Hidden Layers: [16], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6548
# Hidden Layers: [16], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.7010
# Hidden Layers: [16], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.5915
# Hidden Layers: [16], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.5928
# Hidden Layers: [16], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.5986
# Hidden Layers: [16], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6543
# Hidden Layers: [16], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.7369
# Hidden Layers: [16], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.8517
# Hidden Layers: [16], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.9638
# Hidden Layers: [16], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.9683
# Hidden Layers: [16], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.0222
# Hidden Layers: [16], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.5865
# Hidden Layers: [16], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.5824
# Hidden Layers: [16], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.5927
# Hidden Layers: [16], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6004
# Hidden Layers: [16], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6358
# Hidden Layers: [16], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6879
# Hidden Layers: [16], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.9189
# Hidden Layers: [16], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9386
# Hidden Layers: [16], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.9786
# Hidden Layers: [16], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6051
# Hidden Layers: [16], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.5877
# Hidden Layers: [16], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5843
# Hidden Layers: [16], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6096
# Hidden Layers: [16], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6102
# Hidden Layers: [16], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6286
# Hidden Layers: [16], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.7626
# Hidden Layers: [16], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.8894
# Hidden Layers: [16], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.9296
# Hidden Layers: [16], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.5999
# Hidden Layers: [16], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.5796
# Hidden Layers: [16], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6210
# Hidden Layers: [16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6313
# Hidden Layers: [16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6181
# Hidden Layers: [16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.6469
# Hidden Layers: [16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.6860
# Hidden Layers: [16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.7464
# Hidden Layers: [16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.8196
# Hidden Layers: [16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.5752
# Hidden Layers: [16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6060
# Hidden Layers: [16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.5857
# Hidden Layers: [16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6077
# Hidden Layers: [16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6288
# Hidden Layers: [16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6166
# Hidden Layers: [16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.6477
# Hidden Layers: [16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.6750
# Hidden Layers: [16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.7384
# Hidden Layers: [16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6132
# Hidden Layers: [16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.5746
# Hidden Layers: [16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5903
# Hidden Layers: [16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.5862
# Hidden Layers: [16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.5959
# Hidden Layers: [16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6206
# Hidden Layers: [16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6256
# Hidden Layers: [16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6261
# Hidden Layers: [16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.6536
# Hidden Layers: [4, 8], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6750
# Hidden Layers: [4, 8], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6357
# Hidden Layers: [4, 8], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6424
# Hidden Layers: [4, 8], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6405
# Hidden Layers: [4, 8], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6545
# Hidden Layers: [4, 8], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.6409
# Hidden Layers: [4, 8], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.8064
# Hidden Layers: [4, 8], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 1.1517
# Hidden Layers: [4, 8], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.9920
# Hidden Layers: [4, 8], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6578
# Hidden Layers: [4, 8], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6427
# Hidden Layers: [4, 8], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6264
# Hidden Layers: [4, 8], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6380
# Hidden Layers: [4, 8], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6264
# Hidden Layers: [4, 8], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6282
# Hidden Layers: [4, 8], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.6699
# Hidden Layers: [4, 8], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.7091
# Hidden Layers: [4, 8], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.7338
# Hidden Layers: [4, 8], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6419
# Hidden Layers: [4, 8], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6315
# Hidden Layers: [4, 8], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6331
# Hidden Layers: [4, 8], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6279
# Hidden Layers: [4, 8], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6309
# Hidden Layers: [4, 8], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6291
# Hidden Layers: [4, 8], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6422
# Hidden Layers: [4, 8], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6779
# Hidden Layers: [4, 8], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.7458
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6337
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6588
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6368
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6825
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.8997
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.9576
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.9826
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.9767
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.3998
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6048
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6322
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6426
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6382
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6413
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.7699
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.9576
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9648
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.9814
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6675
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.5971
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6152
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6358
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6427
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6428
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.9216
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.9570
# Hidden Layers: [4, 8], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.9626
# Hidden Layers: [4, 8], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.5928
# Hidden Layers: [4, 8], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6423
# Hidden Layers: [4, 8], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6431
# Hidden Layers: [4, 8], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6689
# Hidden Layers: [4, 8], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6428
# Hidden Layers: [4, 8], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.8209
# Hidden Layers: [4, 8], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.9544
# Hidden Layers: [4, 8], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 1.0725
# Hidden Layers: [4, 8], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.9339
# Hidden Layers: [4, 8], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6018
# Hidden Layers: [4, 8], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6296
# Hidden Layers: [4, 8], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6161
# Hidden Layers: [4, 8], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6060
# Hidden Layers: [4, 8], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.5898
# Hidden Layers: [4, 8], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6271
# Hidden Layers: [4, 8], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.8398
# Hidden Layers: [4, 8], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9867
# Hidden Layers: [4, 8], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.9574
# Hidden Layers: [4, 8], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6365
# Hidden Layers: [4, 8], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.5813
# Hidden Layers: [4, 8], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5983
# Hidden Layers: [4, 8], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6225
# Hidden Layers: [4, 8], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.5934
# Hidden Layers: [4, 8], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6338
# Hidden Layers: [4, 8], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6710
# Hidden Layers: [4, 8], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.8447
# Hidden Layers: [4, 8], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.9835
# Hidden Layers: [4, 8], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6352
# Hidden Layers: [4, 8], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6225
# Hidden Layers: [4, 8], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6354
# Hidden Layers: [4, 8], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.7400
# Hidden Layers: [4, 8], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.8734
# Hidden Layers: [4, 8], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.9580
# ...
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.7509
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.9741
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6391
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.5779
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.5676
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.5889
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6045
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6160
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.6437
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.6624
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.6521
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6469
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6131
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5835
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.5840
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6017
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.5869
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6329
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6283
# Hidden Layers: [16, 32], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.6465
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6232
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6337
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6312
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6368
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6290
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.6268
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.7760
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.7555
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.9502
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6348
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6303
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6246
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6377
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6268
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6341
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.6637
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.6914
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.7810
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6347
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6269
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6462
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6328
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6319
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6318
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6373
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6832
# Hidden Layers: [4, 8, 16], Activation: linear, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.6512
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6402
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6467
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6497
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.7070
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.9438
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.9769
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 1.0348
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.9876
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 1.0124
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6183
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6292
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6251
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6487
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6494
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.8743
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.9835
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9872
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.9841
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6161
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6307
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6131
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6358
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6356
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6404
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.9779
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.9693
# Hidden Layers: [4, 8, 16], Activation: sigmoid, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.9869
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6120
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.5657
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.5859
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6529
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6594
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.7547
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.9462
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.9881
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.9950
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.5722
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6229
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6175
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6300
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6622
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6200
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.7509
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.7975
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.9620
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6508
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6243
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.5931
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6108
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6238
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6442
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6632
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6937
# Hidden Layers: [4, 8, 16], Activation: relu, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.8905
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6631
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6454
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6532
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.8585
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.9766
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.9875
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 1.0039
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.9873
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.9902
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6370
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6282
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6312
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6518
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.7110
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.8789
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.9878
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.9876
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 1.0060
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6424
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.6411
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6233
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6332
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6778
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.6769
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.9821
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.9865
# Hidden Layers: [4, 8, 16], Activation: softmax, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.9885
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 16, Test Loss: 0.6337
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 32, Test Loss: 0.6671
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.01, Batch Size: 64, Test Loss: 0.6282
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 16, Test Loss: 0.6424
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 32, Test Loss: 0.6670
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.001, Batch Size: 64, Test Loss: 0.6329
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 16, Test Loss: 0.8657
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 32, Test Loss: 0.8912
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 10, LR: 0.0001, Batch Size: 64, Test Loss: 0.9252
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 16, Test Loss: 0.6236
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 32, Test Loss: 0.6014
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.01, Batch Size: 64, Test Loss: 0.6287
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 16, Test Loss: 0.6201
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 32, Test Loss: 0.6133
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.001, Batch Size: 64, Test Loss: 0.6382
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 16, Test Loss: 0.6698
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 32, Test Loss: 0.6879
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 25, LR: 0.0001, Batch Size: 64, Test Loss: 0.8120
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 16, Test Loss: 0.6188
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 32, Test Loss: 0.5782
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.01, Batch Size: 64, Test Loss: 0.6219
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 16, Test Loss: 0.6220
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 32, Test Loss: 0.6233
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.001, Batch Size: 64, Test Loss: 0.5979
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 16, Test Loss: 0.6489
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 32, Test Loss: 0.6403
# Hidden Layers: [4, 8, 16], Activation: tanh, Epochs: 50, LR: 0.0001, Batch Size: 64, Test Loss: 0.6742
